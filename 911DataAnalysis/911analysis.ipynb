# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('https://storage.googleapis.com/kaggle-data-sets/100/179739/compressed/911.csv.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1586673772&Signature=exHY90Hok88ryaVWYZ4Z8MtFeYo55a4dK5f7aiP4xEq4SDyO0lRLsMiAJyMqGSBJlgq84VFDuMcYay8wKjnGTemG87j8fEgjEgB5UhVqZAYeGdljcQLlNbBtiEgv37KOLskFzFJ1sryqneL%2BwdYjejNbRCsCqHfDO8NXq0jPJwZ7QdgBTtIoTi7CEJ%2F4Wg5mCzgNtgXWdUlc27H%2FLegOpV0OoDkKIapXNymrpKvRgkA%2B483VFhuPxv3EgrmPq4d8fdiRynXzVvnlMNpqGa%2FTwej7UJE%2B9UpbahVav4sXWK05Lvm7PkKVn0D4NGfecbVV8tXk5T5bs2TIPwC5CSMn5w%3D%3D&response-content-disposition=attachment%3B+filename%3D911.csv.zip')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423909 entries, 0 to 423908
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   lat        423909 non-null  float64
#  1   lng        423909 non-null  float64
#  2   desc       423909 non-null  object
#  3   zip        371780 non-null  float64
#  4   title      423909 non-null  object
#  5   timeStamp  423909 non-null  object
#  6   twp        423750 non-null  object
#  7   addr       423909 non-null  object
#  8   e          423909 non-null  int64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 29.1+ MB

# %%
df['Reason']=df['timeStamp'].apply(lambda x:x.split(':')[0])

# %%
df.drop('Reason',axis=1)
df['Reason']=df['title'].apply(lambda x:x.split(':')[0])

# %%
df
# Out:
#               lat        lng  \
# 0       40.297876 -75.581294
# 1       40.258061 -75.264680
# 2       40.121182 -75.351975
# 3       40.116153 -75.343513
# 4       40.251492 -75.603350
# ...           ...        ...
# 423904  40.139993 -75.049864
# 423905  40.270121 -75.382825
# 423906  40.270121 -75.382825
# 423907  40.190946 -75.237285
# 423908  40.155164 -75.264665
#
#                                                      desc      zip  \
# 0       REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1       BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2       HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3       AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4       CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                   ...      ...
# 423904  BUCK RD & WOODWARD DR; LOWER MORELAND; 2018-11...  19006.0
# ...

# %%
type(df['timeStamp'][0])
# Out:
# str

# %%
df['timeStamp']=pd.to_datetime(df['timeStamp'])

# %%
# Out:
# 0        2015-12-10 17:10:52
# 1        2015-12-10 17:29:21
# 2        2015-12-10 14:39:21
# 3        2015-12-10 16:47:36
# 4        2015-12-10 16:56:52
#                  ...
# 423904   2018-11-16 08:54:08
# 423905   2018-11-16 08:53:32
# 423906   2018-11-16 08:54:19
# 423907   2018-11-16 08:51:48
# 423908   2018-11-16 08:46:25
# Name: timeStamp, Length: 423909, dtype: datetime64[ns]

# %%
df['Hour']=df['timeStamp'].apply(lambda x:x.hour)
df['Month']=df['timeStamp'].apply(lambda x:x.month)

# %%
df['Day']=df['timeStamp'].apply(lambda x:x.dayofweek)

# %%
dmap = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}
df['Day']=df['Day'].map(dmap)

# %%
df
# Out:
#               lat        lng  \
# 0       40.297876 -75.581294
# 1       40.258061 -75.264680
# 2       40.121182 -75.351975
# 3       40.116153 -75.343513
# 4       40.251492 -75.603350
# ...           ...        ...
# 423904  40.139993 -75.049864
# 423905  40.270121 -75.382825
# 423906  40.270121 -75.382825
# 423907  40.190946 -75.237285
# 423908  40.155164 -75.264665
#
#                                                      desc      zip  \
# 0       REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1       BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2       HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3       AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4       CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                   ...      ...
# 423904  BUCK RD & WOODWARD DR; LOWER MORELAND; 2018-11...  19006.0
# ...

# %%
import seaborn as sns

# %%
sns.countplot(x='Day',data=df,hue='Reason')

# %%
g=sns.countplot(x='Month',data=df,hue='Reason')
plt.legend(loc='best')

# %%
a=sns.countplot(x='Hour',data=df,hue='Reason', palette="colorblind")

# %%
g=df.groupby('Month').count()
g.head()
# Out:
#          lat    lng   desc    zip  title  timeStamp    twp   addr      e  \
# Month
# 1      37824  37824  37824  33480  37824      37824  37812  37824  37824
# 2      32828  32828  32828  28963  32828      32828  32817  32828  32828
# 3      37666  37666  37666  33416  37666      37666  37651  37666  37666
# 4      33583  33583  33583  29488  33583      33583  33575  33583  33583
# 5      35644  35644  35644  31114  35644      35644  35628  35644  35644
#
#        Reason   Hour    Day
# Month
# 1       37824  37824  37824
# 2       32828  32828  32828
# 3       37666  37666  37666
# 4       33583  33583  33583
# 5       35644  35644  35644

# %%
g['e'].plot()

# %%
g.rename_axis('Month')

f.
# Out:
#          lat    lng   desc    zip  title  timeStamp    twp   addr      e  \
# Month
# 0      37824  37824  37824  33480  37824      37824  37812  37824  37824
# 1      32828  32828  32828  28963  32828      32828  32817  32828  32828
# 2      37666  37666  37666  33416  37666      37666  37651  37666  37666
# 3      33583  33583  33583  29488  33583      33583  33575  33583  33583
# 4      35644  35644  35644  31114  35644      35644  35628  35644  35644
# 5      36171  36171  36171  31501  36171      36171  36152  36171  36171
# 6      36405  36405  36405  31863  36405      36405  36391  36405  36405
# 7      35972  35972  35972  31512  35972      35972  35957  35972  35972
# 8      35339  35339  35339  30772  35339      35339  35325  35339  35339
# 9      37815  37815  37815  32919  37815      37815  37809  37815  37815
# 10     31643  31643  31643  27776  31643      31643  31628  31643  31643
# 11     33019  33019  33019  28976  33019      33019  33005  33019  33019
#
# ...

# %%
g.rename_axis('Month')
# Out:
#          lat    lng   desc    zip  title  timeStamp    twp   addr      e  \
# Month
# 0      37824  37824  37824  33480  37824      37824  37812  37824  37824
# 1      32828  32828  32828  28963  32828      32828  32817  32828  32828
# 2      37666  37666  37666  33416  37666      37666  37651  37666  37666
# 3      33583  33583  33583  29488  33583      33583  33575  33583  33583
# 4      35644  35644  35644  31114  35644      35644  35628  35644  35644
# 5      36171  36171  36171  31501  36171      36171  36152  36171  36171
# 6      36405  36405  36405  31863  36405      36405  36391  36405  36405
# 7      35972  35972  35972  31512  35972      35972  35957  35972  35972
# 8      35339  35339  35339  30772  35339      35339  35325  35339  35339
# 9      37815  37815  37815  32919  37815      37815  37809  37815  37815
# 10     31643  31643  31643  27776  31643      31643  31628  31643  31643
# 11     33019  33019  33019  28976  33019      33019  33005  33019  33019
#
# ...

# %%
sns.lmplot(x='index',y='lat',data=g.reset_index())

# %%
df
# Out:
#               lat        lng  \
# 0       40.297876 -75.581294
# 1       40.258061 -75.264680
# 2       40.121182 -75.351975
# 3       40.116153 -75.343513
# 4       40.251492 -75.603350
# ...           ...        ...
# 423904  40.139993 -75.049864
# 423905  40.270121 -75.382825
# 423906  40.270121 -75.382825
# 423907  40.190946 -75.237285
# 423908  40.155164 -75.264665
#
#                                                      desc      zip  \
# 0       REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1       BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2       HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3       AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4       CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                   ...      ...
# 423904  BUCK RD & WOODWARD DR; LOWER MORELAND; 2018-11...  19006.0
# ...

# %%
df.groupby('Date').count()['zip'].plot(figsize=(30,10))

# %%
f=df[df['Reason']=='Fire'].groupby('Date').count()['zip'].plot(figsize=(30,10))

# %%
df[df['Reason']=='EMS'].groupby('Date').count()['zip'].plot(figsize=(30,10))

# %%
df[df['Reason']=='Traffic'].groupby('Date').count()['zip'].plot(figsize=(30,10))
plt.title('Traffic')
# Out:
# Text(0.5, 1.0, 'Traffic')

# %%
ne=df.groupby(['Day','Hour']).count().unstack()

# %%
sns.heatmap(data=ne,cmap='viridis')

# %%
ne=df.groupby(['Day','Month']).count().unstack()
sns.heatmap(data=ne,cmap='viridis')

# %%
sns.clustermap(ne,cmap='viridis')

# %%
ne=df.groupby(['Day','Hour']).count().unstack()
sns.clustermap(data=ne,cmap='viridis')
